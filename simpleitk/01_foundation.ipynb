# %%
#%pip install SimpleITK

# %%
# check the version: 
import SimpleITK as sitk 
print(sitk.__version__)
# Out:
# 2.5.2

# %% [markdown]
# <br>
# <br>
#
# ### Step to download FJI:
# - wget FJI official page for linux
# - unzip
# - run
# ```bash
# /home/yasin/ImageJ/Fiji.app/ImageJ-linux64
# ```
#
# <br>
# <br>

# %%
# default viewer: wehre we will show image: FJI
image_viwer = sitk.ImageViewer()

# set application: 
image_viwer.SetApplication("/home/yasin/ImageJ/Fiji.app/ImageJ-linux64")

# we need an application for viewing the image:
print(f"application Name: {image_viwer.GetApplication()}")

image_viwer.Execute(sitk.ReadImage(fileName="../cv2CourseEnglish/data/WindowsLogo.jpg"))
# Out:
# application Name: /home/yasin/ImageJ/Fiji.app/ImageJ-linux64
# OpenJDK 64-Bit Server VM warning: ignoring option PermSize=128m; support was removed in 8.0
# OpenJDK 64-Bit Server VM warning: Using incremental CMS is deprecated and will likely be removed in a future release
