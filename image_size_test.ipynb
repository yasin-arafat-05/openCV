# %%
import cv2 as cv 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 


img = cv.imread(filename="cplbackgroundimage/backgroundPhoto.jpg")
img.shape
# Out:
# (1080, 1080, 3)

# %%
cv.rectangle(img,pt1=(300,400),pt2=(800,1080),color=(0,255,0),thickness=-1)
plt.imshow(img)

# %%
all_rounder = cv.imread(filename="cplbackgroundimage/all_rounder.jpg")
batsman = cv.imread(filename="cplbackgroundimage/batsman.jpg")
bowler = cv.imread(filename="cplbackgroundimage/bowler.jpg")
wk_batsman = cv.imread(filename="cplbackgroundimage/wk_batsman.jpg")

all_rounder.shape, batsman.shape,bowler.shape,wk_batsman.shape
# Out:
# ((3375, 3375, 3), (3375, 3375, 3), (3375, 3375, 3), (3375, 3375, 3))

# %%
plt.imshow(all_rounder)
